# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_Model_Forest.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,0,1]])
# Out:
# C:\Users\NEW\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([51636.252])
